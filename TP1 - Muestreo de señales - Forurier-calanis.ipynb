# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
# #### Procesamiento Digital de Señales
#
# # Trabajo Práctico 1
# #### Nombre y Apellido
#
# ***
# ## Muestreo de señales - Fourier

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>1)</b> Se busca realizar una librería en Python que nos permita obtener $N$ muestras de las siguientes señales de período $T_0=1/f_0$, muestreadas a una frecuencia $f_s$ :
#
# </div>

# %% [markdown]
# + **Senoidal**
#
# > $s(k)=A_0.sin(2\pi.k.\frac{ f_0}{f_s} + \phi_0),\space\space \forall k \in \Bbb{R} \wedge k \in (0, N-1)$
#
# + __Ruido__ incorrelado de distribución Gaussiana y parámetros $\mu$ y $\sigma^2$
#
# ***
#
# + (Opcional) __Cuadrada__ con ciclo de actividad $d \in (0,1)$
#
# > $s(k)=A_0,\space\space \forall k \in (0, N.d ]$
#
# > $s(k)=-A_0,\space \forall k \in (N.d, N-1)$
#
# + (Opcional) __Triangular__ con punto de simetría $d \in (0,1)$ y coeficientes $a_{ij} \in \Bbb{R}$
#
# > $s(k)=a_{11}.k/f_s+a_{12},\space\space \forall k \in (0, N.d ]$
#
# > $s(k)=a_{21}.k/f_s+a_{22},\space \forall k \in (N.d, N-1)$

# %% [markdown]
# Es decir que se podría invocar la señal que genere la senoidal de la siguiente manera:

# %%
def generador_senoidal (fs, f0, N, a0=1, p0=0):
    """ 
    
    brief:  Generador de señales senoidal, con argumentos
    
    fs:     frecuencia de muestreo de la señal [Hz]
    N:      cantidad de muestras de la señal a generar
    f0:     frecuencia de la senoidal [Hz]
    a0:     amplitud pico de la señal [V]
    p0:     fase de la señal sinusoidal [rad]
    
    como resultado la señal devuelve:
    
    signal: senoidal evaluada en cada instante 
    tt:     base de tiempo de la señal
    """    

    # comienzo de la función
    def senoidal (N,f00,fss,A,tita) :
    
    
        T0 = 1/f00
        Ts = 1/fss
    
    
        t_base = np.linspace(0,(N-1)*Ts,N)  #Array(lista) de tiempos en los que se analiza el seno 
        s_senoidal = A*np.sin(2*(np.pi)*f00*t_base+tita) #Array(lista) de la funcion seno en los tiempos de sampleo
   
    
    

        return t_base ,s_senoidal 
    
    
    
    
    
    

    
    
    
    # fin de la función

# %% [markdown]
# a) Genere las gráficas asociadas a las siguientes señales de ejemplo para corroborar el correcto funcionamiento de las funciones. Para la presentación de las mismas, tome como referencia la presentación de la siguiente señal respecto a:
#
# * etiquetas indicando cada eje con sus respectivas unidades
# * leyendas indicando cada trazo o color qué representa
# * título de la figura que explique lo que se pretende visualizar
#
#
# <img src="./fig_ejemplo.svg" align="center" width="100%" />
# <img src="./fig_ejemplo2.svg" align="center" width="70%" />

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcParams['figure.figsize']=(10,10)



# Insertar aquí el código para inicializar tu notebook
########################################################

# %%
# NO modifiques este bloque
############################

N  = 1000 # muestras
fs = 1000 # Hz

# %%
##################
# a.1) Senoidal #
#################
a0 = 1 # Volts
p0 = 0 # radianes
f0 = 10   # Hz


# Insertar aquí el código para generar y visualizar la señal
##############################################################
def senoidal (N,f00,fss,A,tita) :
    
    
        T0 = 1/f00
        Ts = 1/fss
    
    
        t_base = np.linspace(0,(N-1)*Ts,N)  #Array(lista) de tiempos en los que se analiza el seno 
        s_senoidal = A*np.sin(2*(np.pi)*f00*t_base+tita) #Array(lista) de la funcion seno en los tiempos de sampleo
   
    
    

        return t_base ,s_senoidal 
   


tt , senial_seno = senoidal (N,f0,fs,a0,p0)



plt.plot(tt, senial_seno,':o', color = 'red') 
plt.title("Señal senoidal") 
plt.xlabel("tiempo [seg]") 
plt.ylabel("Amplitud [V]") 
plt.show()

# %% [markdown]
# ¿Podría inferir la frecuencia de la senoidal a.1 a partir de su representación temporal?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> No,ya que la escala de eje de abcisa no esta escalada en el tiempo.
# </div>

# %%
##################
# a.2) Senoidal #
#################

a0 = 1 # Volts
p0 = 0 # radianes
f0 = fs/2   # Hz

# Insertar aquí el código para generar y visualizar la señal
##############################################################
tt , senial_seno = senoidal (N,f0,fs,a0,p0)



plt.plot(tt, senial_seno,':o', color = 'red') 
plt.title("Señal senoidal") 
plt.xlabel("tiempo [seg]") 
plt.ylabel("Amplitud [V]") 
plt.show()

# %%
##################
# a.3) Senoidal #
#################

a0 = 1       # Volts
p0 = np.pi/2 # radianes
f0 = fs/2    # Hz

# Insertar aquí el código para generar y visualizar la señal
##############################################################

tt , senial_seno = senoidal (N,f0,fs,a0,p0)



plt.plot(tt, senial_seno,':o', color = 'red') 
plt.title("Señal senoidal") 
plt.xlabel("tiempo [seg]") 
plt.ylabel("Amplitud [V]") 
plt.show()

# %% [markdown]
# ¿Y para los casos **a.2** y **a.3** podría conocer los parámetros de la senoidal?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> No se puede reconocer los parametros de la senoidal.
# </div>

# %% [markdown]
# ¿A qué se debe?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> en la señal a.2: se muestrea la señal senoidal en un entorno de n*pi radianes lo que da como resultado
#     valores muy cercanos a cero.
#     en a.3: la señal senoidal se muestrea en multiplos de 1/2*pi por lo que los valores muestreados son todos igual a 1.
# </div>

# %%
##################
# a.4) Senoidal #
#################

a0 = 1     # Volts
p0 = 0     # radianes
f0 = fs+10 # Hz

# Insertar aquí el código para generar y visualizar la señal
##############################################################
tt , senial_seno = senoidal (N,f0,fs,a0,p0)



plt.plot(tt, senial_seno,':o', color = 'red') 
plt.title("Señal senoidal") 
plt.xlabel("tiempo [seg]") 
plt.ylabel("Amplitud [V]") 
plt.show()

# %% [markdown]
# ¿Es posible diferenciar **a.1** de **a.4** a partir de las gráficas?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> No es posible diferenciar ambas señales,ya que la señal a.4 es producto del muestreo con Ts (1 ms) levemente mayor a
#     T0(aprox 0.99 ms) ,con las sucesivas mestras se va obteniendo los distintos puntos de la senoidal y ya que tengo la misma cantidad de las mismas (N=1000) obtengo la misma representacion de señal.
# </div>

# %% [markdown]
# ¿En caso que no, qué solución podría implementar para evitar dicha ambigüedad?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2.a)</b> (Opcional) Implemente un algoritmo que calcule la transformada discreta de Fourier (DFT). Utilice las funciones generadoras de señales de 1) para evaluar y ejemplificar su funcionamiento.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2.b)</b> (Opcional) Compare el tiempo de ejecución de la DFT implementada en con la **FFT** (implementada en **scipy.signal**) en función del tamaño de la señal N. Grafique el tiempo de ejecución de ambos casos en función de N.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Utilice el módulo **timeit** para medir el tiempo transcurrido.
# </div>

# %%
import timeit

the_start = timeit.timeit()
print("hello")
the_end = timeit.timeit()
print(the_start - the_end)
# Out:
# hello
# 0.00568145711440593

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>¡Atención!:</b> Completá la siguiente tabla. Podés guardar tus resultados en la lista **tus_resultados**.
# </div>

# %%
from pandas import DataFrame
from IPython.display import HTML

#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['--'], 
                   [''], # <-- acá debería haber numeritos :)
                   [''], # <-- acá debería haber numeritos :)
                   [''], # <-- acá debería haber numeritos :)
                   [''], # <-- acá debería haber numeritos :)
                   [''], # <-- acá debería haber numeritos :)
                   [''], # <-- acá debería haber numeritos :)
                   [''], # <-- acá debería haber numeritos :)
                   ['']  # <-- acá debería haber numeritos :)
                 ]
df = DataFrame(tus_resultados, columns=['tiempo transcurrido (s)'],
               index=['Tamaño de la señal N', 
                      16, 
                      32, 
                      64, 
                      128,
                      256,
                      512,
                      1024,
                      2048
                     ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tiempo transcurrido (s)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Tamaño de la señal N</th>
#       <td>--</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td></td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td></td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td></td>
#     </tr>
#     <tr>
#       <th>128</th>
#       <td></td>
#     </tr>
#     <tr>
#       <th>256</th>
#       <td></td>
#     </tr>
#     <tr>
#       <th>512</th>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1024</th>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2048</th>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3.a)</b> Verifique el efecto del leakage para una senoidal de $f_0 = f_S/4 + f_D$ siendo $f_D = (0.01,\, 0.25,\, 0.5)$, es decir una frecuencia de desintonía respecto al bin $f_S/4$.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>¡Atención!:</b> Completá la siguiente tabla. Podés guardar tus resultados en la lista **tus_resultados**.
# </div>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from pandas import DataFrame
from IPython.display import HTML



a0 = 1
p0 = 0
N = 1000
fs = 1000

delta_f = fs / N


f0 = (N / 4 )*delta_f

ff = np.linspace(0,(N-1)*delta_f,N)

vect = [100 , 4 , 2]





Nro = (N // 2)

def senoidal (N,f00,fss,A,tita) :
    
    
    T0 = 1/f00
    Ts = 1/fss
    
    
    t_base = np.linspace(0,(N-1)*Ts,N)  #Array(lista) de tiempos en los que se analiza el seno 
    s_senoidal = A*np.sin(2*(np.pi)*f00*t_base+tita) #Array(lista) de la funcion seno en los tiempos de sampleo
   
    
    

    return t_base ,s_senoidal 
   


def fft_calculo(s_seno,f00,N_f0,N ):
    energia_tot = 0
    energia_en_f0=0
    energia_en_f0_mas1=0
    energia_tot_1 = 0
    ff = np.linspace(0,(N-1)*delta_f,N)
    dft = np.fft.fft(s_seno)
    dft_modulo = np.abs(dft)
    mi_dft_mod_esc = (2/N)*dft_modulo
    energia_en_f0 = mi_dft_mod_esc[N_f0]**2
    energia_en_f0_mas1 = mi_dft_mod_esc[N_f0+1]**2
    for I in range(N):
        energia_tot_1 += mi_dft_mod_esc[I]**2
    energia_tot = energia_tot_1 - energia_en_f0    
    mi_dft_mod_db = 20 * np.log10 ( mi_dft_mod_esc )
    return ff , energia_en_f0 ,energia_en_f0_mas1 ,energia_tot ,mi_dft_mod_db


    
    
    
    
    
N_f0= int (f0)

"""señal con f0"""

f00 = (N/4 )*delta_f

t_base ,senial_seno = senoidal(N,f00,fs,a0,p0)

ff , energia_en_f0 ,energia_en_f0_mas1 ,energia_tot ,mi_dft_mod_db = fft_calculo(senial_seno,f00,N_f0,N)    
    
dft_modulo_1 = mi_dft_mod_db [:Nro]

ff_1 = ff[:Nro]

energia_en_f0_0 = energia_en_f0

energia_en_f0_mas1_0 =energia_en_f0_mas1

energia_tot0 = energia_tot



"""SEÑAL CON FD = 0.1 """

f00 = (N/4 + 1/vect[0])*delta_f

t_base ,senial_seno = senoidal(N,f00,fs,a0,p0)

ff , energia_en_f0 ,energia_en_f0_mas1 ,energia_tot ,mi_dft_mod_db = fft_calculo(senial_seno,f00,N_f0,N)    
    
dft_modulo_1 = mi_dft_mod_db [:Nro]

ff_1 = ff[:Nro]

energia_en_f0_1 = energia_en_f0

energia_en_f0_mas1_1 =energia_en_f0_mas1

energia_tot1 = energia_tot

"""SEÑAL CON FD = 0.25 """


f00 = (N/4 + 1/vect[1])*delta_f

t_base , senial_seno = senoidal(N,f00,fs,a0,p0)

ff , energia_en_f0 ,energia_en_f0_mas1 ,energia_tot ,mi_dft_mod_db = fft_calculo(senial_seno,f00,N_f0,N)    
    
dft_modulo_2 = mi_dft_mod_db [:Nro]

ff_2 = ff[:Nro]

energia_en_f0_2 = energia_en_f0

energia_en_f0_mas1_2 =energia_en_f0_mas1

energia_tot2 = energia_tot

"""SEÑAL CON FD = 0.5"""

f00 = (N/4 + 1/vect[2])*delta_f

t_base,senial_seno = senoidal(N,f00,fs,a0,p0)

ff , energia_en_f0 ,energia_en_f0_mas1 ,energia_tot ,mi_dft_mod_db = fft_calculo(senial_seno,f00,N_f0,N)    
    
dft_modulo_3 = mi_dft_mod_db [:Nro]

ff_3 = ff[:Nro]

energia_en_f0_3 = energia_en_f0

energia_en_f0_mas1_3 =energia_en_f0_mas1

energia_tot3 = energia_tot



plt.figure(1)
plt.plot(ff_1, dft_modulo_1,'xb', color = 'red') 
plt.xlabel('delta f') 
plt.ylabel("valor modulo1")

plt.figure(2)
plt.plot(ff_2,dft_modulo_2,'xb', color = 'red') 
plt.xlabel('delta f') 
plt.ylabel("valor modulo2") 

plt.figure(3)
plt.plot(ff_3,dft_modulo_3,'xb', color = 'red') 
plt.xlabel('delta f') 
plt.ylabel("valor modulo3") 



plt.show()

tus_resultados = [ ['$ \lvert X(f_0) \lvert$', '$ \lvert X(f_0+1) \lvert $', '$\sum_{i=F} \lvert X(f_i) \lvert ^2 $'], 
                   ['',                        '',                           '$F:f \neq f_0$'], 
                  [energia_en_f0_0,energia_en_f0_mas1_0,energia_tot0], # <-- acá debería haber numeritos :)
                  [energia_en_f0_1,energia_en_f0_mas1_1,energia_tot1], # <-- acá debería haber numeritos :)
                  [energia_en_f0_2,energia_en_f0_mas1_2,energia_tot2], # <-- acá debería haber numeritos :)
                  [energia_en_f0_3,energia_en_f0_mas1_3,energia_tot3]  # <-- acá debería haber numeritos :)
                 ]
df = DataFrame(tus_resultados, columns=['Frecuencia central', 'Primer adyacente', 'Resto de frecuencias'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '$f_S/4$', 
                      '$f_S/4+0.01$', 
                      '$f_S/4+0.25$', 
                      '$f_S/4+0.5$'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Frecuencia central</th>
#       <th>Primer adyacente</th>
#       <th>Resto de frecuencias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$ \lvert X(f_0) \lvert$</td>
#       <td>$ \lvert X(f_0+1) \lvert $</td>
#       <td>$\sum_{i=F} \lvert X(f_i) \lvert ^2 $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$F:f \neq f_0$</td>
#     </tr>
#     <tr>
#       <th>$f_S/4$</th>
#       <td>1</td>
#       <td>4.09348e-28</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>$f_S/4+0.01$</th>
#       <td>0.999667</td>
#       <td>0.000102038</td>
#       <td>1.00033</td>
#     </tr>
#     <tr>
#       <th>$f_S/4+0.25$</th>
#       <td>0.809297</td>
#       <td>0.0904884</td>
#       <td>1.1887</td>
#     </tr>
#     <tr>
#       <th>$f_S/4+0.5$</th>
#       <td>0.405282</td>
#       <td>0.40529</td>
#       <td>1.59472</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3.b)</b> Verifique qué ocurre si a la señal de $f_0 = f_S/4 + 0.5$ se le agregan ceros para prolongar su duración. Es decir si la señal tiene N muestras, agregue $M_j$ ceros siendo $M_j = ( \frac{N}{10},\, N,\, 10N)$.
# </div>

# %%
# Inserte aquí su código
a0 = 1
p0 = 0
N = 1000
fs = 1000

f0 = (N / 4 + 1/2)*delta_f

def senoidal (N,f00,fss,A,tita) :
    
    
    T0 = 1/f00
    Ts = 1/fss
    
    
    t_base = np.linspace(0,(N-1)*Ts,N)  #Array(lista) de tiempos en los que se analiza el seno 
    s_senoidal = A*np.sin(2*(np.pi)*f00*t_base+tita) #Array(lista) de la funcion seno en los tiempos de sampleo

    

    return t_base,s_senoidal

"""ventana de tamaño N/10"""
N__pri = int ((1/10) * N)               #cantidad de muestras adicionales en cero que agrega la ventana cuatrada
N_pri= N__pri + N                  #cantidad total de muestras
escala = N_pri / (N / 2)
w = np.zeros(((N__pri),),np.integer)

delta_f = fs / N
delta_f_pri=fs/N_pri

ff = np.linspace(0,(N_pri-1)*delta_f_pri,N_pri)
t_base_1 ,senial_seno1 = senoidal(N,f0,fs,a0,p0)

X = np.concatenate((senial_seno1,w),axis=None)

dft_ej1 = np.fft.fft(X)

dft_modulo_a = np.abs(dft_ej1 )

dft_modulo_a1 = (escala/N_pri)*dft_modulo_a

dft_modulo1 = 20 * np.log10(dft_modulo_a1)

Nro = N_pri//2

dft_modulo_1 = dft_modulo1 [:Nro]
ff_1 = ff[:Nro]
plt.figure(1)
plt.plot(ff_1, dft_modulo_1,':o', color = 'blue') 
plt.xlabel('delta f') 
plt.ylabel("valor modulo") 

"""ventana de tamaño N"""
N__pri = int ((1/1) * N)               #cantidad de muestras adicionales en cero que agrega la ventana cuatrada
N_pri= N__pri + N                  #cantidad total de muestras
escala = N_pri / (N / 2)
w2 = np.zeros(((N__pri),),np.integer)

delta_f = fs / N
delta_f_pri=fs/N_pri

ff2 = np.linspace(0,(N_pri-1)*delta_f_pri,N_pri)
t_base_2 ,senial_seno2 = senoidal(N,f0,fs,a0,p0)

X2 = np.concatenate((senial_seno2,w2),axis=None)

dft_ej2 = np.fft.fft(X2)

dft_modulo_a2 = np.abs(dft_ej2 )

dft_modulo_a_2 = (escala/N_pri)*dft_modulo_a2

dft_modulo2 = 20 * np.log10(dft_modulo_a_2)

Nro2 = N_pri//2

dft_modulo_2 = dft_modulo2 [:Nro2]
ff_2 = ff[:Nro2]
plt.figure(2)
plt.plot(ff_2, dft_modulo_2,':o', color = 'blue') 
plt.xlabel('delta f') 
plt.ylabel("valor modulo")

"""ventana de tamaño 10*N"""
N__pri = int ((10/1) * N)               #cantidad de muestras adicionales en cero que agrega la ventana cuatrada
N_pri= N__pri + N                  #cantidad total de muestras
escala = N_pri / (N / 2)
w3 = np.zeros(((N__pri),),np.integer)

delta_f = fs / N
delta_f_pri=fs/N_pri

ff3= np.linspace(0,(N_pri-1)*delta_f_pri,N_pri)
t_base_3 ,senial_seno3 = senoidal(N,f0,fs,a0,p0)

X3 = np.concatenate((senial_seno3,w3),axis=None)

dft_ej3 = np.fft.fft(X3)

dft_modulo_a3 = np.abs(dft_ej3 )

dft_modulo_a_3 = (escala/N_pri)*dft_modulo_a3

dft_modulo3 = 20 * np.log10(dft_modulo_a_3)

Nro3 =N_pri//2

dft_modulo_3 = dft_modulo3 [:Nro3]
ff_3 = ff3[:Nro3]
plt.figure(3)
plt.plot(ff_3, dft_modulo_3,':o', color = 'blue') 
plt.xlabel('delta f') 
plt.ylabel("valor modulo")




plt.show()

# %% [markdown]
# **3.c)** ¿Ha variado la resolución espectral en los casos de 3.b?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Si, ha variado el espectro en los distintos casos.
# </div>

# %% [markdown]
# **3.d)** ¿Cuál es el efecto que se produce en cada caso? Esta técnica se conoce como Zero padding.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> la variacion en el espectro se debe a que la señal en el tiempo discreto al agregar muestras en ceros es equivalente a multiplicar la señal senoidal con una ventana en el dominio del tiempo discreto lo que en el dominio tranformado implica comvolucionar el espectro de la señal senoidal con el espectro de la ventana (la cual es un espectro con la forma de sinc).al variar las cantidad de muestras varia la duracion de la ventana por lo que la forma del espectro tambien se modifica.
# </div>

# %% [markdown]
# **3.e)** Analice cuál es la frecuencia  $\hat{f}_0 = \mathop{arg\ max}_f \{\lvert X(f) \rvert \}$ a la que ocurre el máximo del espectro y en cuánto difiere de $f_0$ en términos porcentuales.

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

a0 = 1
p0 = 0
N = 1000
fs = 1000
delta_f = fs / N

f0 = (N / 4 + 1/2)*delta_f



def senoidal (N,f00,fss,A,tita) :
    
    
    T0 = 1/f00
    Ts = 1/fss
    
    
    t_base = np.linspace(0,(N-1)*Ts,N)  #Array(lista) de tiempos en los que se analiza el seno 
    s_senoidal = A*np.sin(2*(np.pi)*f00*t_base+tita) #Array(lista) de la funcion seno en los tiempos de sampleo

    

    return t_base,s_senoidal

"""ventana de tamaño N/10"""
N__pri = int ((1/10) * N)               #cantidad de muestras adicionales en cero que agrega la ventana cuatrada
N_pri= N__pri + N                  #cantidad total de muestras
escala = N_pri / (N / 2)
ff_pos_f0 = 0
w = np.zeros(((N__pri),),np.integer)

delta_f_pri=fs/N_pri

ff = np.linspace(0,(N_pri-1)*delta_f_pri,N_pri)
t_base_1 ,senial_seno1 = senoidal(N,f0,fs,a0,p0)

X = np.concatenate((senial_seno1,w),axis=None)

dft_ej1 = np.fft.fft(X)

dft_modulo_a = np.abs(dft_ej1 )

dft_modulo_a1 = (escala/N_pri)*dft_modulo_a

arg_max = np.amax(dft_modulo_a1)

for J in range(N_pri//2):
    if dft_modulo_a1[J]==arg_max:
        pos_arg_max = J

ff_pos_f0 =  int (f0/(fs/N_pri))

f_pico = pos_arg_max * delta_f_pri

error = ((f_pico - f0)/f0)*100

dft_modulo1 = 20 * np.log10(dft_modulo_a1)

Nro = (N_pri // 2)

dft_modulo_1 = dft_modulo1 [:Nro]
ff_1 = ff[:Nro]

"""ventana de tamaño N"""
N__pri = int ((1/1) * N)               #cantidad de muestras adicionales en cero que agrega la ventana cuatrada
N_pri= N__pri + N                  #cantidad total de muestras
escala = N_pri / (N / 2)
ff_pos_f02 = 0
w2 = np.zeros(((N__pri),),np.integer)


delta_f_pri=fs/N_pri

ff2 = np.linspace(0,(N_pri-1)*delta_f_pri,N_pri)
t_base_2 ,senial_seno2 = senoidal(N,f0,fs,a0,p0)

X2 = np.concatenate((senial_seno2,w2),axis=None)

dft_ej2 = np.fft.fft(X2)

dft_modulo_a2 = np.abs(dft_ej2 )

dft_modulo_a_2 = (escala/N_pri)*dft_modulo_a2

arg_max2 = np.amax(dft_modulo_a_2)


for J in range(N_pri//2):
    if dft_modulo_a_2[J]==arg_max2:
        pos_arg_max2 = J
f_pico2 = pos_arg_max2 * delta_f_pri

error2 = ((f_pico2 - f0)/f0)*100
        
ff_pos_f02 =  int (f0/(fs/N_pri))
        
dft_modulo2 = 20 * np.log10(dft_modulo_a_2)

Nro = (N_pri // 2)

dft_modulo_2 = dft_modulo2 [:Nro]
ff_2 = ff[:Nro]


"""ventana de tamaño 10*N"""
N__pri = int ((10/1) * N)               #cantidad de muestras adicionales en cero que agrega la ventana cuatrada
N_pri= N__pri + N                  #cantidad total de muestras
escala = N_pri / (N / 2)
ff_pos_f03 = 0
w3 = np.zeros(((N__pri),),np.integer)


delta_f_pri=fs/N_pri

ff3= np.linspace(0,(N_pri-1)*delta_f_pri,N_pri)
t_base_3 ,senial_seno3 = senoidal(N,f0,fs,a0,p0)

X3 = np.concatenate((senial_seno3,w3),axis=None)

dft_ej3 = np.fft.fft(X3)

dft_modulo_a3 = np.abs(dft_ej3 )

dft_modulo_a_3 = (escala/N_pri)*dft_modulo_a3

arg_max3 = np.amax(dft_modulo_a_3)



for J in range(N_pri//2):
    if dft_modulo_a_3[J]==arg_max:
        pos_arg_max3 = J
        
f_pico3 = pos_arg_max3 * delta_f_pri

error3 = ((f_pico3 - f0)/f0)*100



ff_pos_f03 =  int (f0/(fs/N_pri))
        


dft_modulo3 = 20 * np.log10(dft_modulo_a_3)

Nro = (N_pri // 2)

dft_modulo_3 = dft_modulo3 [:Nro]
ff_3 = ff3[:Nro]



tus_resultados = ['', # <-- acá debería haber numeritos :)
                  error, # <-- acá debería haber numeritos :)
                  error2, # <-- acá debería haber numeritos :)
                  error3 # <-- acá debería haber numeritos :)
                 ]
df = DataFrame(tus_resultados, columns=['$e_\%$'],
               index=['0',
                      '$N/10$', 
                      '$N$', 
                      '$10N$'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>$e_\%$</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td></td>
#     </tr>
#     <tr>
#       <th>$N/10$</th>
#       <td>0.16331</td>
#     </tr>
#     <tr>
#       <th>$N$</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>$10N$</th>
#       <td>0.16331</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>4)</b>
# Para cada señal propuesta complete los valores que se indican en las siguientes consignas.
# </div>

# %% [markdown]
# + En la tabla de resultados de cada inciso, en la fila indicada con **predicción** responda conceptualmente qué contenido espectral debería obtener tras evaluar su FFT (sin realizar ninguna simulación).
# + Calcule su espectro y discuta la predicción con los resultados obtenidos de la **simulación**. Intente discutir las diferencias si las hubiera en las respuestas de cada inciso.
# + Preste especial atención en su discusión a:
#   * La energía total de la señal
#   * La energía del tono en particular
#   * La localización del tono en el espectro
# + Siga las indicaciones particulares para cada señal.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Las siguientes señales pueden generarse a partir de una senoidal *patrón* siguiendo las consignas de la derecha.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./1.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.a) Senoidal
# 				de **energía normalizada** y frecuencia $f_0 = 9 \cdot f_S/N$. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################
from pandas import DataFrame
from IPython.display import HTML

f0 = 9 * (fs / N)

a0 = 1

p0 = 0

delta_f = fs / N

energia_tot = 0

tt , senial_seno = senoidal (N , f0 , fs , a0 ,p0)

mi_dft = np.fft.fft (senial_seno)

ff = np.linspace (0 , (N-1) * delta_f , N)

mi_dft_modulo = np.abs ( mi_dft )

mi_dft_mod_esc = (2/N)*mi_dft_modulo

for J in range(N//2):                       #Calculo de la energia total
    energia_tot += mi_dft_mod_esc[J]**2

for J in range(N):                          #Busco la posicion de la f0       
    if (delta_f * J) == f0:
        ff_pos_f0 = J

energia_en_f0 = mi_dft_mod_esc[ff_pos_f0]**2

energia_en_arg_max = np.amax(mi_dft_mod_esc)**2

mi_dft_mod_db = 20 * np.log10 ( mi_dft_mod_esc )

nro =  (N // 2)

ff_plot = ff[:nro]

mi_dft_modulo_db_plot = mi_dft_mod_db [:nro]

plt.figure(1)

plt.plot(tt, senial_seno,':o',color = 'blue') 
plt.title("Señal senoidal") 
plt.xlabel('tiempo') 
plt.ylabel("valor amplitud")

plt.figure (2)
plt.plot(ff_plot, mi_dft_modulo_db_plot,':o', color = 'red') 
 
plt.xlabel('delta f') 
plt.ylabel("valor modulo")
plt.show()



tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['1', '1', '1'], 
                  ['', '', ''], # <-- completar acá
                  ['', '', ''], 
                  [energia_tot, energia_en_f0, energia_en_arg_max]  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./2.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.b) **1 solo ciclo** de la misma senoidal
# 				de **energía normalizada** y frecuencia $f_0 = 9 \cdot f_S/N$. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################
fs = 1000

N = 1000

f0 = 9 * (fs / N)

a0 = 1

p0 = 0

delta_f = fs / N

energia_tot = 0
energia_en_f0 = 0
energia_en_arg_max = 0

pos_al_1er_ciclo = int ((1/f0)//(1/fs))



mi_array = np.zeros((N,),np.float)




mi_array [:pos_al_1er_ciclo] = 1

tt , senial_seno = senoidal (N , f0 , fs , a0 ,p0)

s_seno_1ciclo = senial_seno * mi_array    #ME QUEDO CON UN CICLO DE LA SEÑAL SENOIDAL

mi_dft = np.fft.fft (s_seno_1ciclo)

ff = np.linspace (0 , (N-1) * delta_f , N)

mi_dft_modulo = np.abs ( mi_dft )

mi_dft_mod_esc = (2/N)*mi_dft_modulo

for J in range(N//2):                       #Calculo de la energia total
    energia_tot += mi_dft_mod_esc[J]**2

for J in range(N):                          #Busco la posicion de la f0       
    if (delta_f * J) == f0:
        ff_pos_f0 = J

energia_en_f0 = mi_dft_mod_esc[ff_pos_f0]**2

energia_en_arg_max = np.amax(mi_dft_mod_esc)**2

mi_dft_mod_db = 20 * np.log10 ( mi_dft_mod_esc )

nro =  (N // 2)

ff_plot = ff[:nro]

mi_dft_modulo_db_plot = mi_dft_mod_db [:nro]

plt.figure(1)

plt.plot(tt, s_seno_1ciclo,':o',color = 'blue') 
plt.title("Señal senoidal") 
plt.xlabel('tiempo') 
plt.ylabel("valor amplitud")

plt.figure (2)
plt.plot(ff_plot, mi_dft_modulo_db_plot,':o', color = 'red') 
 
plt.xlabel('delta f') 
plt.ylabel("valor modulo")

plt.show()



tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['', '', ''], # <-- completar acá
                  ['', '', ''], 
                  [energia_tot,energia_en_f0,energia_en_arg_max]  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td>0.111111</td>
#       <td>0.0123456</td>
#       <td>0.0132857</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Observe el resultado y compare sus resultados con el punto anterior. ¿Qué ha cambiado? ¿Cuánto vale la energía de un solo ciclo de senoidal respecto al caso anterior?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> En este caso el espectro se modifica ya que la señal se podria interpretar como el producto de la señal senoidal con una ventana cuya duracion es igual a 9 peridos de la senoidal(zero padding).En cuanto la energia ,esta disminuye a 1/9 del caso anterior ya que tenemos un ciclo en un rango de tiempo igual a 9 periodos de la senoidal.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./3.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.c) 1 solo ciclo de la misma senoidal
# 				de energía normalizada y frecuencia $f_0 = 9 \cdot f_S/N$ **pero demorado un tiempo igual a dos ciclos**. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################


fs = 1000

N = 1000

f0 = 9 * (fs / N)

a0 = 1

p0 = 0

delta_f = fs / N

energia_tot = 0
energia_en_f0 = 0
energia_en_arg_max = 0

pos_al_1er_ciclo = int ((1/f0)//(1/fs))



mi_array = np.zeros((N,),np.float)




mi_array [2*pos_al_1er_ciclo :3*pos_al_1er_ciclo] = 1






tt , senial_seno  = senoidal (N , f0 , fs , a0 ,p0)

s_seno_1ciclo = senial_seno * mi_array    #ME QUEDO CON UN CICLO DE LA SEÑAL SENOIDAL

mi_dft = np.fft.fft (s_seno_1ciclo)

ff = np.linspace (0 , (N-1) * delta_f , N)

mi_dft_modulo = np.abs ( mi_dft )

mi_dft_mod_esc = (2/N)*mi_dft_modulo

for J in range(N//2):                       #Calculo de la energia total
    energia_tot += mi_dft_mod_esc[J]**2

for J in range(N):                          #Busco la posicion de la f0       
    if (delta_f * J) == f0:
        ff_pos_f0 = J

energia_en_f0 = mi_dft_mod_esc[ff_pos_f0]**2

energia_en_arg_max = np.amax(mi_dft_mod_esc)**2
    


mi_dft_mod_db = 20 * np.log10 ( mi_dft_mod_esc )

nro =  (N // 2)

ff_plot = ff[:nro]

mi_dft_modulo_db_plot = mi_dft_mod_db [:nro]

plt.figure(1)

plt.plot(tt, s_seno_1ciclo,':o',color = 'blue') 
plt.title("Señal senoidal") 
plt.xlabel('tiempo') 
plt.ylabel("valor amplitud")

plt.figure (2)
plt.plot(ff_plot, mi_dft_modulo_db_plot,':o', color = 'red') 
 
plt.xlabel('delta f') 
plt.ylabel("valor modulo")






plt.show()

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['', '', ''], # <-- completar acá
                  ['', '', ''], 
                  [energia_tot, energia_en_f0,energia_en_arg_max]  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td>0.111111</td>
#       <td>0.0123456</td>
#       <td>0.013283</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# En este caso, ¿Qué ha cambiado respecto al anterior? ¿Cómo se manifiesta en el dominio frecuencial?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b>  El espectro de amplitud no se modifica ya que la señal es la misma que la anterior pero desplazada en el tiempo , dicho desplazamiento solo modifica el espectro de fase.En cuanto a energia no hay variaciones ya que espectro de amplitud es el mismo.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./4.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.d) 1 solo ciclo de la misma senoidal utilizada hasta ahora, y otro ciclo de idénticas características pero de $f_1 = 8 \cdot f_S/N$ y demorado aproximadamente como se observa a la izquierda. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################
fs = 1000

N = 1000

f0 = 9 * (fs / N)

f02 = 8 * (fs / N) 

a0 = 1

p0 = 0

delta_f = fs / N

energia_tot = 0
energia_en_f0 = 0
energia_en_arg_max = 0

pos_al_1er_ciclo = int ((1/f0)/(1/fs))

pos_al_1er_ciclo2 = int ((1/f02)/(1/fs))



mi_array = np.zeros((N,),np.float)

mi_array_2 = np.zeros((N,),np.float)





mi_array [:pos_al_1er_ciclo] = 1

mi_array_2 [(4*pos_al_1er_ciclo2 ):5*pos_al_1er_ciclo2] = 1








tt , senial_seno = senoidal (N , f0 , fs , a0 ,p0)

tt2 , senial_seno2  = senoidal (N , f02 , fs , a0 , p0)

s_seno_1ciclo = senial_seno * mi_array    #ME QUEDO CON UN CICLO DE LA SEÑAL SENOIDAL

s_seno_1ciclo_s2 = senial_seno2 * mi_array_2    #ME QUEDO CON UN CICLO DE LA SEÑAL SENOIDAL

s_seno_total = s_seno_1ciclo + s_seno_1ciclo_s2 



mi_dft = np.fft.fft (s_seno_total)

ff = np.linspace (0 , (N-1) * delta_f , N)

mi_dft_modulo = np.abs ( mi_dft )

mi_dft_mod_esc = (2/N)*mi_dft_modulo

for J in range(N//2):                       #Calculo de la energia total
    energia_tot += mi_dft_mod_esc[J]**2

for J in range(N):                          #Busco la posicion de la f0       
    if (delta_f * J) == f0:
        ff_pos_f0 = J

energia_en_f0 = mi_dft_mod_esc[ff_pos_f0]**2

energia_en_arg_max = np.amax(mi_dft_mod_esc)**2
    

mi_dft_mod_db = 20 * np.log10 ( mi_dft_mod_esc )

nro =  (N // 2)

ff_plot = ff[:nro]

mi_dft_modulo_db_plot = mi_dft_mod_db [:nro]



plt.figure(1)
#plt.subplot(3,1,1)
plt.plot(tt2, s_seno_total,':o',color = 'blue') 
plt.title("Señal senoidal") 
plt.xlabel('tiempo') 
plt.ylabel("valor amplitud")



plt.figure (2)
plt.plot(ff_plot, mi_dft_modulo_db_plot,':o', color = 'red') 
#plt.title("Señal senoidal") 
plt.xlabel('delta f') 
plt.ylabel("valor modulo")






plt.show()

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['', '', ''], # <-- completar acá
                  ['', '', ''], 
                  [energia_tot, energia_en_f0, energia_en_arg_max]  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td>0.236111</td>
#       <td>0.00195259</td>
#       <td>0.056082</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ¿Puede localizar ambas componentes en este espectro? ¿Cómo lo haría?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./5.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.e) Idéntico al caso anterior salvo que se invierte la ocurrencia de las señales. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

fs = 1000

N = 1000

f0 = 9 * (fs / N)

f02 = 8 * (fs / N) 

a0 = 1

p0 = 0

delta_f = fs / N

energia_tot = 0
energia_en_f0 = 0
energia_en_arg_max = 0

pos_al_1er_ciclo = int ((1/f0)/(1/fs))

pos_al_1er_ciclo2 = int ((1/f02)/(1/fs))


mi_array = np.zeros((N,),np.float)

mi_array_2 = np.zeros((N,),np.float)





mi_array [4*pos_al_1er_ciclo+1:5*pos_al_1er_ciclo+1] = 1

mi_array_2 [:pos_al_1er_ciclo2] = 1







tt , senial_seno = senoidal (N , f0 , fs , a0 ,p0)

tt2 , senial_seno2  = senoidal (N , f02 , fs , a0 , p0)

s_seno_1ciclo = senial_seno * mi_array    #ME QUEDO CON UN CICLO DE LA SEÑAL SENOIDAL

s_seno_1ciclo_s2 = senial_seno2 * mi_array_2    #ME QUEDO CON UN CICLO DE LA SEÑAL SENOIDAL

s_seno_total = s_seno_1ciclo + s_seno_1ciclo_s2 



mi_dft = np.fft.fft (s_seno_total)

ff = np.linspace (0 , (N-1) * delta_f , N)

mi_dft_modulo = np.abs ( mi_dft )

mi_dft_mod_esc = (2/N)*mi_dft_modulo

for J in range(N//2):                       #Calculo de la energia total
    energia_tot += mi_dft_mod_esc[J]**2

for J in range(N):                          #Busco la posicion de la f0       
    if (delta_f * J) == f0:
        ff_pos_f0 = J

energia_en_f0 = mi_dft_mod_esc[ff_pos_f0]**2

energia_en_arg_max = np.amax(mi_dft_mod_esc)**2
    

mi_dft_mod_db = 20 * np.log10 ( mi_dft_mod_esc )

nro =  (N // 2)

ff_plot = ff[:nro]

mi_dft_modulo_db_plot = mi_dft_mod_db [:nro]



plt.figure(1)

plt.plot(tt2, s_seno_total,':o',color = 'blue') 
plt.title("Señal senoidal") 
plt.xlabel('tiempo') 
plt.ylabel("valor amplitud")



plt.figure (2)
plt.plot(ff_plot, mi_dft_modulo_db_plot,':o', color = 'red') 
 
plt.xlabel('delta f') 
plt.ylabel("valor modulo")

plt.show()

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['', '', ''], # <-- completar acá
                  ['', '', ''], 
                  [energia_tot, energia_en_f0, energia_en_arg_max]  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td>0.236111</td>
#       <td>0.04903</td>
#       <td>0.0577596</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ¿ha cambiado el espectro respecto al caso anterior? ¿Si solo dispone del espectro, puede decir cuál ha ocurrido antes? ¿Resulta útil el análisis de espectral mediante la transformada de Fourier en este caso?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> El espectro es identico al anterior,no es posible discernir la secuencia de ocurrencia por lo que en este caso no es practico analizar el espectro.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./6.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.f) Arme una señal como la que se muestra a la izquierda, concatenando 3 ciclos de $f_0 = 9 \cdot f_S/N$.</span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

fs = 1000

N = 1000

f0 = 9 * (fs / N)

a0 = 1

p0 = 0

delta_f = fs / N

energia_tot = 0
energia_en_f0 = 0
energia_en_arg_max = 0

pos_al_1er_ciclo = int ((1/f0)//(1/fs))



mi_array = np.zeros((N,),np.float)




mi_array [:3*pos_al_1er_ciclo] = 1







tt , senial_seno  = senoidal (N , f0 , fs , a0 ,p0)

s_seno_1ciclo = senial_seno * mi_array    #ME QUEDO CON UN CICLO DE LA SEÑAL SENOIDAL

mi_dft = np.fft.fft (s_seno_1ciclo)

ff = np.linspace (0 , (N-1) * delta_f , N)

mi_dft_modulo = np.abs ( mi_dft )

mi_dft_mod_esc = (2/N)*mi_dft_modulo

for J in range(N//2):                       #Calculo de la energia total
    energia_tot += mi_dft_mod_esc[J]**2

for J in range(N):                          #Busco la posicion de la f0       
    if (delta_f * J) == f0:
        ff_pos_f0 = J

energia_en_f0 = mi_dft_mod_esc[ff_pos_f0]**2

energia_en_arg_max = np.amax(mi_dft_mod_esc)**2
    

mi_dft_mod_db = 20 * np.log10 ( mi_dft_mod_esc )

nro =  (N // 2)

ff_plot = ff[:nro]

mi_dft_modulo_db_plot = mi_dft_mod_db [:nro]

plt.figure(1)
#plt.subplot(3,1,1)
plt.plot(tt, s_seno_1ciclo,':o',color = 'blue') 
plt.title("Señal senoidal") 
plt.xlabel('tiempo') 
plt.ylabel("valor amplitud")

plt.figure (2)
plt.plot(ff_plot, mi_dft_modulo_db_plot,':o', color = 'red') 
#plt.title("Señal senoidal") 
plt.xlabel('delta f') 
plt.ylabel("valor modulo")






plt.show()

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['', '', ''], # <-- completar acá
                  ['', '', ''], 
                  [energia_tot, energia_en_f0, energia_en_arg_max]  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td>0.333333</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ¿Qué energía tiene la componente $f_0$ en el espectro en comparación con la señal donde los 9 ciclos estaban presentes? ¿Y respecto a la que solo había 1 ciclo?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Con respecto a la señal de 9 ciclos la energia es un tercio de esta ,lo cual es esperado dado que la señal es distinta de cero un tercio respecto del tiempo total de analisis.
# Y con respecto a la señal de un ciclo la energia es 3 veces mayor por equivalentes motivos.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./7.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.g) Idem anterior, pero cada ciclo con amplitudes (1, 5, 3).</span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

fs = 1000

N = 1000

f0 = 9 * (fs / N)

a01 = 1

a02 = 5

a03 = 3

p0 = 0

delta_f = fs / N

energia_tot = 0
energia_en_f0 = 0
energia_en_arg_max = 0


pos_al_1er_ciclo = int ((1/f0)//(1/fs))


mi_array1 = np.zeros((N,),np.float)

mi_array2 = np.zeros((N,),np.float)

mi_array3 = np.zeros((N,),np.float)




mi_array1 [:pos_al_1er_ciclo] = 1

mi_array2 [pos_al_1er_ciclo:2*pos_al_1er_ciclo] = 1

mi_array3 [2*pos_al_1er_ciclo:3*pos_al_1er_ciclo] = 1








tt1 , senial_seno1  = senoidal (N , f0 , fs , a01 ,p0)

tt2 , senial_seno2  = senoidal (N , f0 , fs , a02 ,p0)

tt3 , senial_seno3  = senoidal (N , f0 , fs , a03 ,p0)

s_seno_1ciclo1 = senial_seno1 * mi_array1    #ME QUEDO CON UN CICLO DE LA SEÑAL SENOIDAL

s_seno_1ciclo2 = senial_seno2 * mi_array2

s_seno_1ciclo3 = senial_seno3 * mi_array3

s_seno_total = s_seno_1ciclo1 + s_seno_1ciclo2 + s_seno_1ciclo3 



mi_dft = np.fft.fft (s_seno_total)

ff = np.linspace (0 , (N-1) * delta_f , N)

mi_dft_modulo = np.abs ( mi_dft )

mi_dft_mod_esc = (2/N)*mi_dft_modulo

for J in range(N//2):                       #Calculo de la energia total
    energia_tot += mi_dft_mod_esc[J]**2

for J in range(N):                          #Busco la posicion de la f0       
    if (delta_f * J) == f0:
        ff_pos_f0 = J

energia_en_f0 = mi_dft_mod_esc[ff_pos_f0]**2

energia_en_arg_max = np.amax(mi_dft_mod_esc)**2
    

mi_dft_mod_db = 20 * np.log10 ( mi_dft_mod_esc )

nro =  (N // 2)

ff_plot = ff[:nro]

mi_dft_modulo_db_plot = mi_dft_mod_db [:nro]

plt.figure(1)
#plt.subplot(3,1,1)
plt.plot(tt1, s_seno_total,':o',color = 'blue') 
plt.title("Señal senoidal") 
plt.xlabel('tiempo') 
plt.ylabel("valor amplitud")

plt.figure (2)
plt.plot(ff_plot, mi_dft_modulo_db_plot,':o', color = 'red') 
#plt.title("Señal senoidal") 
plt.xlabel('delta f') 
plt.ylabel("valor modulo")





plt.show()

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['', '', ''], # <-- completar acá
                  ['', '', ''], 
                  [energia_tot,energia_en_f0, energia_en_arg_max]  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td>3.88888</td>
#       <td>0.999995</td>
#       <td>0.999995</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ¿Qué energía tiene la componente $f_0$ en el espectro en comparación con el inciso anterior?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b>La energia en f0 para esta señal es aproximadamente 9 veces mayor a la señal de los 3 ciclos con amplitud unitaria.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./8.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.h) Idem patrón anterior, pero repetido 3 veces.</span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

fs = 1000

N = 1000

f0 = 9 * (fs / N)

a01 = 1

a02 = 5

a03 = 3

p0 = 0

delta_f = fs / N

energia_tot = 0
energia_en_f0 = 0
energia_en_arg_max = 0

pos_al_1er_ciclo = int ((1/f0)//(1/fs))



mi_array1 = np.zeros((N,),np.float)

mi_array2 = np.zeros((N,),np.float)

mi_array3 = np.zeros((N,),np.float)

s_seno = np.zeros((N,),np.float)



mi_array1 [:pos_al_1er_ciclo] = 1

mi_array2 [pos_al_1er_ciclo:2*pos_al_1er_ciclo] = 1

mi_array3 [2*pos_al_1er_ciclo:3*pos_al_1er_ciclo] = 1








tt1 , senial_seno1  = senoidal (N , f0 , fs , a01 ,p0)

tt2 , senial_seno2  = senoidal (N , f0 , fs , a02 ,p0)

tt3 , senial_seno3  = senoidal (N , f0 , fs , a03 ,p0)

s_seno_1ciclo1 = senial_seno1 * mi_array1    #ME QUEDO CON UN CICLO DE LA SEÑAL SENOIDAL

s_seno_1ciclo2 = senial_seno2 * mi_array2

s_seno_1ciclo3 = senial_seno3 * mi_array3

s_seno_total = s_seno_1ciclo1 + s_seno_1ciclo2 + s_seno_1ciclo3 

s_seno[:3*pos_al_1er_ciclo] = s_seno_total[:3*pos_al_1er_ciclo]

s_seno[3*pos_al_1er_ciclo:6*pos_al_1er_ciclo] = s_seno_total[:3*pos_al_1er_ciclo]

s_seno[6*pos_al_1er_ciclo:9*pos_al_1er_ciclo] = s_seno_total[:3*pos_al_1er_ciclo] 


mi_dft = np.fft.fft (s_seno)

ff = np.linspace (0 , (N-1) * delta_f , N)

mi_dft_modulo = np.abs ( mi_dft )

mi_dft_mod_esc = (2/N)*mi_dft_modulo

for J in range(N//2):                       #Calculo de la energia total
    energia_tot += mi_dft_mod_esc[J]**2

for J in range(N):                          #Busco la posicion de la f0       
    if (delta_f * J) == f0:
        ff_pos_f0 = J

energia_en_f0 = mi_dft_mod_esc[ff_pos_f0]**2

energia_en_arg_max = np.amax(mi_dft_mod_esc)**2
    


mi_dft_mod_db = 20 * np.log10 ( mi_dft_mod_esc )

nro =  (N // 2)

ff_plot = ff[:nro]

mi_dft_modulo_db_plot = mi_dft_mod_db [:nro]

plt.figure(1)

plt.plot(tt1, s_seno,':o',color = 'blue') 
plt.title("Señal senoidal") 
plt.xlabel('tiempo') 
plt.ylabel("valor amplitud")

plt.figure (2)
plt.plot(ff_plot, mi_dft_modulo_db_plot,':o', color = 'red') 

plt.xlabel('delta f') 
plt.ylabel("valor modulo")





plt.show()

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['', '', ''], # <-- completar acá
                  ['', '', ''], 
                  [energia_tot, energia_en_f0, energia_en_arg_max]  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td>11.6666</td>
#       <td>8.99782</td>
#       <td>8.99782</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ¿Qué energía tiene la componente $f_0$ en el espectro en comparación con el inciso anterior? ¿Y respecto al que estaban los 9 ciclos presentes pero con la misma amplitud?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Con respecto a la señal anterior la energia en f0 es mucho mayor ya que la señal es continua en todo el periodo de analisis,y con respecto a la señal unitaria tambien es mucho mayor debido a la mayor amplitud en los distintos ciclos,.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./9.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">4.i) En este caso genere un ciclo de $f_0 = 9 \cdot f_S/N$, y seguido otro ciclo pero desfasado $\pi$ radianes.</span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

fs = 1000

N = 1000

f0 = 9 * (fs / N)

a0 = 1

p01 = 0

p02 = np.pi

delta_f = fs / N

energia_tot = 0
energia_en_f0 = 0
energia_en_arg_max = 0

pos_al_1er_ciclo = int ((1/f0)//(1/fs))



mi_array1 = np.zeros((N,),np.float)

mi_array2 = np.zeros((N,),np.float)






mi_array1 [:pos_al_1er_ciclo] = 1

mi_array2 [pos_al_1er_ciclo:2*pos_al_1er_ciclo] = 1









tt1 , senial_seno1 = senoidal (N , f0 , fs , a0 ,p01)

tt2 , senial_seno2 = senoidal (N , f0 , fs , a0 ,p02)



s_seno_1ciclo1 = senial_seno1 * mi_array1    #ME QUEDO CON UN CICLO DE LA SEÑAL SENOIDAL

s_seno_1ciclo2 = senial_seno2 * mi_array2



s_seno_total = s_seno_1ciclo1 + s_seno_1ciclo2 



mi_dft = np.fft.fft (s_seno_total)

ff = np.linspace (0 , (N-1) * delta_f , N)

mi_dft_modulo = np.abs ( mi_dft )

mi_dft_mod_esc = (2/N)*mi_dft_modulo

for J in range(N//2):                       #Calculo de la energia total
    energia_tot += mi_dft_mod_esc[J]**2

for J in range(N):                          #Busco la posicion de la f0       
    if (delta_f * J) == f0:
        ff_pos_f0 = J

energia_en_f0 = mi_dft_mod_esc[ff_pos_f0]**2

energia_en_arg_max = np.amax(mi_dft_mod_esc)**2
    


mi_dft_mod_db = 20 * np.log10 ( mi_dft_mod_esc )

nro =  (N // 2)

ff_plot = ff[:nro]

mi_dft_modulo_db_plot = mi_dft_mod_db [:nro]

plt.figure(1)
#plt.subplot(3,1,1)
plt.plot(tt1, s_seno_total,':o',color = 'blue') 
plt.title("Señal senoidal") 
plt.xlabel('tiempo') 
plt.ylabel("valor amplitud")

plt.figure (2)
plt.plot(ff_plot, mi_dft_modulo_db_plot,':o', color = 'red') 
#plt.title("Señal senoidal") 
plt.xlabel('delta f') 
plt.ylabel("valor modulo")





plt.show()

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['', '', ''], # <-- completar acá
                  ['', '', ''], 
                  [energia_tot, energia_en_f0, energia_en_arg_max]  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td>0.222222</td>
#       <td>1.95158e-12</td>
#       <td>0.0393596</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ¿Qué energía tiene la componente $f_0$ en el espectro en comparación con el que estaba un solo ciclo presente?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b>En este caso la energia en f0 es mucho menor ya que lo que se tiene son dos ciclos de una señal senoidal de la misma amplitud que estan en contra fase.
# </div>

# %% [markdown]
# Luego de realizar la experimentación y observando los resultados obtenidos discuta si es fiable o no medir en el dominio de Fourier, por medio de la FFT los siguientes aspectos de una señal:
#
#     • Energía
#     • Contenido espectral
#     • Energía de un determinado ancho de banda o componente espectral
#     • Localización temporal de un determinado componente espectral.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5)</b>
# Simule el efecto de cuantizar una señal continua en el tiempo mediante un conversor analógico digital (ADC).
# </div>

# %% [markdown]
# Para ello analice señales determinísticas, por ejemplo una senoidal de **energía normalizada** y frecuencia $f_0$, y otras que varíen de forma más aleatoria y por lo tanto, representativa de una señal real, por ejemplo añadiendo ruido. Es decir que la señal *real* simulada será
#
# $$s_R = s + n$$
#
# donde la señal $n$ debe tener una energía de $1/10$.
#
# Puede simular una señal continua (aproximadamente para los fines prácticos), mediante una señal muestreada a una $f^1_S$ muy alta en comparación con las $f_S$  que quiere estudiar, y un tipo de dato de doble precisión (double o float de 64 bits). De esta manera se asegura una grilla de cuantización (en tiempo y amplitud) mucho más densa que la que se va a simular. Se pide cuantizar a palabras de 4, 8 y 16 bits, obteniendo
#
# $$ s_Q = \mathop{Q}_i \{s_R\} \quad i \in (4, 8, 16) $$
#
# Siendo $\mathop{Q}_i$ la función **no lineal** responsable de la cuantización a *i-* bits de la señal real $s_R$. Describa el ruido de cuantización
#
# $$ e = s_Q - s_R$$
#
# para las 3 situaciones antedichas siguiendo las siguientes consignas.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5.a)</b>
# La señal temporal $e$ y su espectro $E$.
# </div>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame
from IPython.display import HTML

N = 1000
fs = 1000
b=np.array([4,8,16])   #Numero dde bits del conversor
delta_f = fs / N
ff = np.linspace(0,(N-1)*delta_f,N)
eqmean= np.array([0.0,0.0,0.0])
eqvar= np.array([0.0,0.0,0.0])
eq_bits=np.array([0.0,0.0,0.0])
eerror_bits=np.array([0.0,0.0,0.0])
eq_rms= np.array([0.0,0.0,0.0])
eq_mediana=np.array([0.0,0.0,0.0])
eq_dstr=np.array([0.0,0.0,0.0])
a0 = 2**(0.5)
p0 = 0
f0 = 15
dc=0
varianza=0.1
media=0.0

def senoidal (nn,ff,fs,A,tita,dc) :
    T0 = 1/ff
    Ts = 1/fs
    t_base = np.linspace(0,(nn-1)*Ts,nn)  #Array(lista) de tiempos en los que se analiza el seno 
    s_senoidal = dc + A*np.sin(2*(np.pi)*ff*t_base+tita) #Array(lista) de la funcion seno en los tiempos de sampleo
    return t_base ,s_senoidal 



tt , s = senoidal (N,f0,fs,a0,p0,dc)

def calculo_energia_f (s):
    sf=np.abs(np.fft.fft(s))*(1/N)
    l=len(sf)
    sff=sf[:int(l/2)]
    energia=np.sum(sff**2)*2
    return energia

def calc_rms(si) :
    
    rms=np.sqrt(np.sum(si**2)/N)
    
    return rms

    
ii=0
potencia=0
#for jj in range(N):
#    potencia+=s[jj]**2
potencia=np.sum((s)**2)/N

so=s+np.random.normal(0,0.1**2,N)

e_so=calculo_energia_f(so)

for ii in np.arange(3):
    nn = 2**(b[ii]-1)-1
    q = 1 / nn
    ss=so*nn
    sq =  (np.around(ss))
    eq = sq - ss
    eqnoesc=eq*q
    eq_bits[ii]=calculo_energia_f(sq/nn)
    eerror_bits[ii]=calculo_energia_f(eq)
    eqmean[ii] = np.mean(eq)
    eqvar[ii] = np.var(eq)
    eq_rms[ii]=calc_rms(eq)
    #eq_mediana[ii]=np.median(eq)
    eq_dstr[ii]=np.std(eq)
    eqspectral=np.fft.fft(eqnoesc)
    eqsmodule = np.absolute(eqspectral)*(2/N)
    plt.figure()
    plt.subplot(3,1,1)
    #plt.plot(tt, so,color = 'red',label=r'señal original') 
    plt.plot(tt, sq,color = 'blue',label=r'señal cuantizada')
    
    plt.title("Señal senoidal cuantizada con "+str( b[ii])+ " bits") 
    plt.xlabel('tiempo') 
    plt.ylabel("valor amplitud")
    plt.subplot(3,1,2)
    plt.plot(eq,color = 'green')
    
    plt.plot(np.array([0,N]),np.array([-1/2,-1/2]),'--r')
    plt.plot(np.array([0,N]),np.array([1/2,1/2]),'--r')
    #plt.title(" señal error ") 
    plt.xlabel('tiempo') 
    plt.ylabel("señal error")
    plt.subplot(3,1,3)
    plt.plot(ff[:int(N/2)],10*np.log10(eqsmodule[:int(N/2)]),color='blue')
   
    plt.xlabel('delta f') 
    plt.ylabel("espectro de la señal error ")
    plt.show()
    
    
    
tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert S_R(f) \rvert ^2$', '$\sum_{f=0}^{f_S/2} \lvert S_Q(f) \rvert ^2$', '$\sum_{f=0}^{f_S/2} \lvert e(f) \rvert ^2$' ], 
                   ['',                                             '',                                             ''                              ], 
                   [e_so, eq_bits[0], eerror_bits[0]], # <-- completar acá
                   [e_so, eq_bits[1], eerror_bits[1]], # <-- completar acá
                   [e_so, eq_bits[2], eerror_bits[2]], # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía total Q', 'Energía total $e$'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '4 bits', 
                      '8 bits', 
                      '16 bits'
                      ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía total Q</th>
#       <th>Energía total $e$</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert S_R(f) \rvert ^2$</td>
#       <td>$\sum_{f=0}^{f_S/2} \lvert S_Q(f) \rvert ^2$</td>
#       <td>$\sum_{f=0}^{f_S/2} \lvert e(f) \rvert ^2$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4 bits</th>
#       <td>1.00046</td>
#       <td>1.01292</td>
#       <td>0.081569</td>
#     </tr>
#     <tr>
#       <th>8 bits</th>
#       <td>1.00046</td>
#       <td>1.00062</td>
#       <td>0.0851049</td>
#     </tr>
#     <tr>
#       <th>16 bits</th>
#       <td>1.00046</td>
#       <td>1.00046</td>
#       <td>0.0846669</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5.b)</b> El histograma de la señal $e_i$ para cada tamaño de palabra.
# </div>

# %%
#####################################
# Tu simulación que genere gráficas #
#####################################

a0 = 2**(0.5)
p0 = 0
f0 = 15
dc=0
varianza=0.1
media=0.0
eq=np.zeros((N,3))

def senoidal (nn,ff,fs,A,tita,dc) :
    T0 = 1/ff
    Ts = 1/fs
    t_base = np.linspace(0,(nn-1)*Ts,nn)  #Array(lista) de tiempos en los que se analiza el seno 
    s_senoidal = dc + A*np.sin(2*(np.pi)*ff*t_base+tita) #Array(lista) de la funcion seno en los tiempos de sampleo
    return t_base ,s_senoidal 



tt , s = senoidal (N,f0,fs,a0,p0,dc)

so=s+np.random.normal(media,varianza**2,N)


for ii in range(3):
    nn = 2**(b[ii]-1)-1
    q = 1 / nn
    ss=so*nn
    sq =  (np.around(ss))
    eq [:,ii]= sq - ss
    e=eq[:,ii]
    plt.figure()
    plt.hist(eq[:,ii])
    plt.title("Histograma del error para "+str(b[ii])+ " Bits")
    plt.show()

# %% [markdown]
# ¿Qué información podemos obtener de esta forma de analizar la señal $e_i$?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Podemos comprobar que la forma del histograma del error de cuantizacion para los distintos conversores se puede aproximar a una distribucion uniforme para el error normalizado entre -0.5 y 0.5,no existiendo
# valores de error fuera de este rango.vemos que esto coincide con lo observado en el grafico temporal del error.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5.c)</b> Una descripción de la señal $e_i$, por medio del **valor medio**, su valor **RMS** y su energía **energía**
# </div>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ 
                   [eqmean[0], eq_rms[0], eerror_bits[0]], # <-- completar acá
                   [eqmean[1], eq_rms[1], eerror_bits[1]], # <-- completar acá
                   [eqmean[2], eq_rms[2], eerror_bits[2]], # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Valor medio', 'RMS', 'Energía'],
               index=[
                      '4 bits', 
                      '8 bits', 
                      '16 bits'
                      ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Valor medio</th>
#       <th>RMS</th>
#       <th>Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4 bits</th>
#       <td>0.004371</td>
#       <td>0.285681</td>
#       <td>0.081569</td>
#     </tr>
#     <tr>
#       <th>8 bits</th>
#       <td>-0.011842</td>
#       <td>0.291521</td>
#       <td>0.085105</td>
#     </tr>
#     <tr>
#       <th>16 bits</th>
#       <td>-0.011830</td>
#       <td>0.290772</td>
#       <td>0.084667</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5.d)</b> Una descripción **estadística** de la señal $e_i$, por medio de su **media**, su **desvío estándard** y su energía **varianza**.
# </div>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ 
                   [eqmean[0], eq_dstr[0], eqvar[0]], # <-- completar acá
                   [eqmean[1], eq_dstr[1], eqvar[1]], # <-- completar acá
                   [eqmean[2], eq_dstr[2], eqvar[2]], # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Media', 'Desvío estándard', 'Varianza'],
               index=[
                      '4 bits', 
                      '8 bits', 
                      '16 bits'
                      ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Media</th>
#       <th>Desvío estándard</th>
#       <th>Varianza</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4 bits</th>
#       <td>0.004371</td>
#       <td>0.285647</td>
#       <td>0.081594</td>
#     </tr>
#     <tr>
#       <th>8 bits</th>
#       <td>-0.011842</td>
#       <td>0.291281</td>
#       <td>0.084844</td>
#     </tr>
#     <tr>
#       <th>16 bits</th>
#       <td>-0.011830</td>
#       <td>0.290532</td>
#       <td>0.084409</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Discutir las similitudes y diferencias con los parámetros calculados en **c)** y **d)**.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Observando y comparande los valores hallados vemos que los valores de energia y varianza,valor RMS
#     y desvio estandar son aproximadamente iguales .Esto podemos aceptarlo ya que la señal analizada no tiene valor DC
#     definido ya que esta condicion la energia equivale a la varianza y el valor RMS al desvio estandar.
# </div>
